# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Always state the H0 and H1 before conducting the hypothesis test.
# - Happy learning!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
data = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
data.head(10)
# Out:
#                       Name                               Job Titles  \
# 0   ADRIANO,  RACQUEL ANNE                                PARAMEDIC
# 1        AFFANEH,  MAHIR A                           POLICE OFFICER
# 2        AFOENYI,  PHYLLIS                TITLE V PROGRAM TRAINEE I
# 3          AGAR,  BULENT B                      DEPUTY COMMISSIONER
# 4          AGEE,  LAWRENCE                           POLICE OFFICER
# 5        AGNEW,  ANTONIO E                       MOTOR TRUCK DRIVER
# 6        AGNEW,  MELISSA M                                 SERGEANT
# 7        AGOSTA,  JOSEPH J   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 8  AGOSTINELLI,  MICHAEL A  FIREFIGHTER (PER ARBITRATORS AWARD)-EMT
# 9        AGOSTINI,  LUIS R                                 ASST DIR
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0              FIRE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# ...

# %%
data.shape
# Out:
# (33702, 8)

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
data.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25528
# Annual Salary         8174
# Hourly Rate          25528
# dtype: int64

# %%
8174+25528
# Out:
# 33702

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
data.pivot_table(index=['Salary or Hourly'], values = ['Name'],aggfunc = ['count']).reset_index()
# Out:
#   Salary or Hourly  count
#                      Name
# 0           Hourly   8174
# 1           Salary  25528

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:

data.pivot_table(index=['Department'], values = ['Annual Salary', 'Hourly Rate'],aggfunc = ['count']).reset_index()
# Out:
#              Department         count
#                         Annual Salary Hourly Rate
# 0          ADMIN HEARNG            38           0
# 1         ANIMAL CONTRL            63          12
# 2              AVIATION           642        1214
# 3     BOARD OF ELECTION           111           0
# 4       BOARD OF ETHICS             8           0
# 5         BUDGET & MGMT            42           2
# 6             BUILDINGS           258           0
# 7      BUSINESS AFFAIRS           160           7
# 8            CITY CLERK            88           0
# 9          CITY COUNCIL           288          74
# 10                 COPA           123           0
# 11     CULTURAL AFFAIRS            64          10
# 12                 DAIS           288         745
# 13         DISABILITIES            27           1
# 14     FAMILY & SUPPORT           299         357
# 15              FINANCE           499          45
# 16                 FIRE          4627           0
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
import scipy.stats

# %%
from scipy.stats import ttest_1samp

# %%
# Two-sided test:
#H0 : hourly wage >< 30$/h
#H1 : hourly wage = 30$/h

# %%
hourly = data.dropna(subset=['Hourly Rate'])

# %%
hourly
# Out:
#                          Name                      Job Titles  \
# 2           AFOENYI,  PHYLLIS       TITLE V PROGRAM TRAINEE I
# 5           AGNEW,  ANTONIO E              MOTOR TRUCK DRIVER
# 15         AGSALUD,  FERNAN S              SANITATION LABORER
# 16     AGSALUD JR,  JUANITO S              SANITATION LABORER
# 21            AGUAYO,  LUIS M            LABORER - APPRENTICE
# ...                       ...                             ...
# 33676         ZUNIGA,  THOMAS           GENERAL LABORER - DSS
# 33678             ZUNO,  ERIK            CONSTRUCTION LABORER
# 33681      ZURAWSKI,  JEFFREY  FRM OF MACHINISTS - AUTOMOTIVE
# 33684         ZUREK,  FRANCIS             ELECTRICAL MECHANIC
# 33688      ZWARYCZ,  THOMAS J              MOTOR TRUCK DRIVER
#
#                 Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 2         FAMILY & SUPPORT                 P           Hourly           20.0
# ...

# %%
hourly.shape
# Out:
# (8174, 8)

# %%
hourly.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Annual Salary        float64
# Hourly Rate          float64
# dtype: object

# %%
confidence_level = 0.95
degrees_freedom = len(hourly) - 1
sample_mean = np.mean(hourly['Hourly Rate'])
sample_standard_error = scipy.stats.sem(hourly['Hourly Rate'])
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
stat, pval = ttest_1samp(hourly['Hourly Rate'], 30)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   31.211500329216044
# pvalue for the two-tailed test is  3.825475847673794e-202

# %%
# The pvalue is almost = 0
# So we reject H0 => The hourly wage is significantly different from 30$/h

# %%
sample_mean
# Out:
# 34.58644971862002

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our Null hypothesis is less than or equal to, then to reject, the test statistic must be positive (rejects the <) and the p-value below 0.05 (rejects the =).

# %%
# Your code here:
data['Department'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                    FIRE
# 1                  POLICE
# 2        FAMILY & SUPPORT
# 3             WATER MGMNT
# 4                  POLICE
#                ...
# 33697              POLICE
# 33698              POLICE
# 33699              POLICE
# 33700              POLICE
# 33701                DAIS
# Name: Department, Length: 33702, dtype: object>

# %%
annually = data.dropna(subset=['Annual Salary'])

# %%
police_force = annually.loc[annually['Department'] == 'POLICE']

# %%
police_force
# Out:
#                        Name                              Job Titles  \
# 1         AFFANEH,  MAHIR A                          POLICE OFFICER
# 4           AGEE,  LAWRENCE                          POLICE OFFICER
# 6         AGNEW,  MELISSA M                                SERGEANT
# 7         AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 1         POLICE                 F           Salary            NaN
# ...

# %%
# One-sided test:
#H0 : annual wage >= 86000$
#H1 : annual wage < 86000$

# %%
confidence_level = 0.95
degrees_freedom = len(police_force) - 1
sample_mean = np.mean(police_force['Annual Salary'])
sample_standard_error = scipy.stats.sem(police_force['Annual Salary'])
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
stat, pval = ttest_1samp(police_force['Annual Salary'], 86000)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval/2)
# Out:
# stat is   18.51748561981861
# pvalue for the two-tailed test is  6.119566952121482e-76

# %%
# the pvalue is almost 0 but the stat does to the same direction as our H0. 
# We can accept H0

# %%
sample_mean
# Out:
# 88834.11892361111

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
data.pivot_table(index=['Department'], values = ['Hourly Rate'],aggfunc = ['count']).reset_index()
# Out:
#              Department       count
#                         Hourly Rate
# 0          ADMIN HEARNG           0
# 1         ANIMAL CONTRL          12
# 2              AVIATION        1214
# 3     BOARD OF ELECTION           0
# 4       BOARD OF ETHICS           0
# 5         BUDGET & MGMT           2
# 6             BUILDINGS           0
# 7      BUSINESS AFFAIRS           7
# 8            CITY CLERK           0
# 9          CITY COUNCIL          74
# 10                 COPA           0
# 11     CULTURAL AFFAIRS          10
# 12                 DAIS         745
# 13         DISABILITIES           1
# 14     FAMILY & SUPPORT         357
# 15              FINANCE          45
# 16                 FIRE           0
# 17               HEALTH           2
# 18              HOUSING           0
# 19   HOUSING & ECON DEV           3
# 20      HUMAN RELATIONS           0
# 21      HUMAN RESOURCES           0
# 22        INSPECTOR GEN           0
# 23                  LAW          48
# ...

# %%
salary_min = pd.crosstab(index=data['Department'], columns='count', values=data['Hourly Rate'], aggfunc='count').idxmin()[0]

# %%
salary_min
# Out:
# 'ADMIN HEARNG'

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
hourly_max = pd.crosstab(index=data['Department'], columns='count', values=data['Hourly Rate'], aggfunc='count').idxmax()[0]

# %%
hourly_max
# Out:
# 'STREETS & SAN'

# %%
streets_san = hourly.loc[hourly['Department'] == 'STREETS & SAN']
streets_san
# Out:
#                          Name               Job Titles     Department  \
# 15         AGSALUD,  FERNAN S       SANITATION LABORER  STREETS & SAN
# 16     AGSALUD JR,  JUANITO S       SANITATION LABORER  STREETS & SAN
# 26           AGUILAR,  EFRAIN       SANITATION LABORER  STREETS & SAN
# 49     ABDUL-SHAKUR,  TAHIR J  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 65          ABRAMS,  SAMUEL A  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# ...                       ...                      ...            ...
# 33623        ZIZUMBO,  JOSE N       MOTOR TRUCK DRIVER  STREETS & SAN
# 33624          ZIZUMBO,  LUIS       MOTOR TRUCK DRIVER  STREETS & SAN
# 33667        ZUMMO,  ROBERT J       MOTOR TRUCK DRIVER  STREETS & SAN
# 33668     ZUNICH,  JONATHAN G       SANITATION LABORER  STREETS & SAN
# 33676         ZUNIGA,  THOMAS    GENERAL LABORER - DSS  STREETS & SAN
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# ...

# %%
# H0 the wage < 35$/h
# H1 the wage >= 35$/h

# %%
confidence_level = 0.95
degrees_freedom = len(streets_san) - 1
sample_mean = np.mean(streets_san['Hourly Rate'])
sample_standard_error = scipy.stats.sem(streets_san['Hourly Rate'])
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
stat, pval = ttest_1samp(police_force['Annual Salary'], 35)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval/2)
# Out:
# stat is   580.1931577470259
# pvalue for the two-tailed test is  0.0

# %%
# the pvalue is almost 0 but the stat does to the same direction as our H0. 
# We can accept H0

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
from scipy.stats import t

# %%
confidence_level = 0.95
degrees_freedom = len(hourly) - 1
sample_mean = np.mean(hourly['Hourly Rate'])
sample_standard_error = scipy.stats.sem(hourly['Hourly Rate'])
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)
print( 'confidence interval is ', confidence_interval)
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865)

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
confidence_level = 0.95
degrees_freedom = len(police_force) - 1
sample_mean = np.mean(police_force['Annual Salary'])
sample_standard_error = scipy.stats.sem(police_force['Annual Salary'])
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)
print( 'confidence interval is ', confidence_interval)
# Out:
# confidence interval is  (88534.1182885883, 89134.11955863392)

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
